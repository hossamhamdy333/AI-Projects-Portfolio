# %% [markdown]
# <a href="https://colab.research.google.com/github/hossamhamdy333/AI-Projects-Portfolio/blob/main/machine-learning-projects/life-satisfaction-prediction/Life_satisfaction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hossamhamdy333/AI-Projects-Portfolio.git
# Out:
# Cloning into 'AI-Projects-Portfolio'...
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 188 (delta 8), reused 5 (delta 5), pack-reused 177 (from 1)
# Receiving objects: 100% (188/188), 3.82 MiB | 4.12 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
from pathlib import Path
path_data=(Path("/content/AI-Projects-Portfolio")
/ "machine-learning-projects"
/ "life-satisfaction-prediction"
/ "data"
)
path_data.mkdir(parents=True,exist_ok=True)
